# %%
# %load_ext autoreload
# %autoreload 2

from analysis import *

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# module://ipykernel.pylab.backend_inline
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc

# %%
# DenseNet vs. SqueezeNet
param_name = 'focal_length'
stat_name = 'map'
label_dict = {
    'baseline': 'DenseNet161', 
    'exp62': 'ResNet152', 
    'vgg16-alt2': 'VGG16', 
    'squeezenet-alt': 'SqueezeNet1.1',
    'alexnet-alt2': 'AlexNet',
}
compare_models(
    [label_dict[i] for i in label_dict], 
    ['/data/sepsense/experiments/{}/logs'.format(i) for i in label_dict], 
    [5]*len(label_dict), 
    param_name, stat_name, std=False, resample=False, smooth=False, norm_list=[False, True], niirs_list=False,
    figsize=(2*8, 6),
    legend_pos=(1.0, 0.3),
    show_random=True,
    legend_title='Architecture',
    save_file=None)
# Out:
# module://ipykernel.pylab.backend_inline
# /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/matplotlibrc
# Num folds found: 10
# Num folds found: 10
# Num folds found: 10
# Num folds found: 10
# Num folds found: 10
# Fig size: [6.0, 4.0]
# Fig size: [6.0, 4.0]
# (<Figure size 1152x432 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7d5550e5f8>,
# ...
#        dtype=object))
